# %%
! git clone https://github.com/kelseymatsik/project_chd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('/content/project_chd/fhs_test.csv')
df.head()
# Out:
# Cloning into 'project_chd'...
# remote: Enumerating objects: 96, done.
# remote: Counting objects: 100% (35/35), done.
# remote: Compressing objects: 100% (14/14), done.
# remote: Total 96 (delta 28), reused 21 (delta 21), pack-reused 61
# Receiving objects: 100% (96/96), 2.37 MiB | 12.70 MiB/s, done.
# Resolving deltas: 100% (54/54), done.
#    Unnamed: 0  sex  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0         674    0   58        1.0              1        20.0     0.0
# 1        4070    0   51        3.0              0         0.0     0.0
# 2        3150    0   44        2.0              1         9.0     0.0
# 3        1695    0   40        2.0              1        20.0     0.0
# 4        2692    1   58        2.0              1        20.0     0.0
#
#    prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                0             0         0      NaN  126.0   77.0  30.08
# ...

# %%
sns.histplot(df['cigsPerDay'], bins = 10)
plt.title('Cigarettes Per Day')
# Out:
# Text(0.5, 1.0, 'Cigarettes Per Day')

# %%
sns.histplot(df['age'], bins = 9, kde=True, edgecolor = 'black')
plt.title('Age')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.histplot(df['totChol'], bins = 20, kde=True, edgecolor='black')
plt.title('Cholesterol')
# Out:
# Text(0.5, 1.0, 'Cholesterol')
